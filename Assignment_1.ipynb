# %%
#1. Write a function named show_message() that prints "Welcome to Python". Call the function.

def show_message():
    print("Welcome to Python")
show_message()
# Out:
# Welcome to Python

# %%
#2. Write a function named show_name() that prints your name. Call the function.

def show_name():
    print("Sagar")
show_name()
# Out:
# Sagar

# %%
#3. Write a function named show_number() that prints the number 50. Call the function.

def show_number():
    print(50)
show_number()
# Out:
# 50

# %%
#4. Write a function named print_subject() that prints the name of a subject. Call the function.

def print_subject():
    print("Physics")
print_subject()
# Out:
# Physics

# %%
#5. Write a function named add() that takes two numbers as arguments and prints their sum. Call it with 10 and 20.

def add(a,b):
    print(a+b)
add(10,20)
# Out:
# 30

# %%
#6. Write a function named multiply() that takes two numbers as arguments and prints their product. Call it with 6 and 8. 

def multiply(a,b):
    print(a*b)
multiply(6,8)
# Out:
# 48

# %%
#7. Write a function named greet_student() that takes a student's name as an argument and prints "Hello" followed by the name.

def greet_student(name):
    print("Hello ",name)
greet_student('Vishal')
# Out:
# Hello  Vishal

# %%
#8. Write a function named display_marks() that takes three subject marks as arguments and prints all three marks.

def display_marks(phy,bio,chem):
    print('Physics: ',phy)
    print('Biology: ',bio)
    print('Chemistry: ',chem)
display_marks(98,78,87)
# Out:
# Physics:  98
# Biology:  78
# Chemistry:  87

# %%
#9. Write a function named square() that takes a number as an argument and returns its square. Print the returned value.

def square(a):
    return a*a
square(25)
# Out:
# 625

# %%
#10. Write a function named cube() that takes a number as an argument and returns its cube. Print the returned value.

def cube(a):
    return a*a*a
cube(2)
# Out:
# 8

# %%
#11. Write a function named subtract() that takes two numbers as arguments and returns their difference. Test it with 50 and 15.

def subtract(a,b):
    return b-a
subtract(15,50)
# Out:
# 35

# %%
#12. Write a function named area_rectangle() that takes length and width as arguments and returns the area of the rectangle.

def area_rectangle(length,width):
    return print('Area of rectangle is: ',length*width)
area_rectangle(50,10)
# Out:
# Area of rectangle is:  500

# %%
#13. Write a function named get_age() that takes no argument but returns an age value. Store the returned value in a variable and print it.

def get_age():
    age = 69
    return age
get_age()
# Out:
# 69

# %%
#14. Write a function named get_city() that takes no argument but returns the name of a city. Print the returned value.

def get_city():
    city = 'Mumbai'
    print(city)
get_city()
# Out:
# Mumbai

# %%
#15. Write a function named calculate_total() that takes price and quantity as arguments and returns the total amount.

def calculate_total(price,qty):
    return print("Total amount is: ",price*qty)
calculate_total(100,5)
# Out:
# Total amount is:  500

# %%
#16. Write a function named find_average() that takes three numbers as arguments and returns their average.

def find_average(a,b,c):
    return print("Average: ",(a+b+c)/3)
find_average(4,6,8)
# Out:
# Average:  6.0

# %%
#17. Write a function named check_number() that takes a number as an argument and prints whether the number is positive or negative.

def check_number(a):
    return print("Given number is ","Positive" if a>=0 else "Negative")
check_number(-56)
# Out:
# Given number is  Negative

# %%
#18. Write a function named largest() that takes two numbers as arguments and returns the larger number.

def largest(a,b):
    return print("Larger number is ",max(a,b))
largest(56,87)
# Out:
# Larger number is  87

# %%
#19. Write a function named is_even() that takes a number as an argument and prints whether the number is even or odd.

def is_even(a):
    return print("Number is","even" if a % 2 == 0 else "odd")
is_even(54)
# Out:
# Number is even

# %%
#20. Write a function named calculate_discount() that takes price and discount percentage as arguments and returns the final price after discount

def calculate_discount(price,dis):
    return print("Final price after discount is ",price-price*dis/100)
calculate_discount(200,8)
# Out:
# Final price after discount is  184.0
