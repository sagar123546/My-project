# %%
from array import array

# %%
#Q1. Create an array of 5 integers and display all the elements. 

numbers = array('i',[2,5,2,45,24])
print(numbers)
# Out:
# array('i', [2, 5, 2, 45, 24])

# %%
#Q2. Create an array of 5 numbers and display the first element. 

numbers = array('i',[54,65,24,6,45])
print(number[0])
# Out:
# 54

# %%
#Q3. Create an array of 5 numbers and display the last element. 

numbers = array('i',[34,65,34,7,8])
print(numbers[-1])
# Out:
# 8

# %%
#Q4. Create an array of 5 numbers and change the third element to 100. 

numbers = array('i',[45,65,44,56,24])
numbers[2] = 100
print(numbers)
# Out:
# array('i', [45, 65, 100, 56, 24])

# %%
#Q5. Create an array of 5 numbers and add a new element at the end. 

numbers = array('i',[53,45,87,11,25])
numbers.append(1000)
print(numbers)
# Out:
# array('i', [53, 45, 87, 11, 25, 1000])

# %%
#Q6. Create an array of 5 numbers and remove one element from the array. 

numbers = array('i',[64,58,77,8,5])
numbers.remove(77)
print(numbers)
# Out:
# array('i', [64, 58, 8, 5])

# %%
#Q7. Create an array of 5 numbers and find its length. 

numbers = array('i',[54,87,25,55,11])
print(len(numbers))
# Out:
# 5

# %%
#Q8. Create an array of numbers and display all elements using a for loop. 

numbers = array('i',[54,87,55,66,45,98,77])
for number in numbers:
    print(number)
# Out:
# 54
# 87
# 55
# 66
# 45
# 98
# 77

# %%
#Q9. Create an array of numbers and check whether 50 is present in the array.

num = array('i',[45,87,55,65,4])
print(50 in num)
# Out:
# False

# %%
#Q10. Create an array of numbers and find the largest element without using the max() function. 

numbers = array('i',[54,78,5,4,5])
a = sorted(numbers)
print('Largest: ',a[-1])
# Out:
# Largest:  78

# %%
#Q11. Create an array of 5 integers and change the last element to 100. 

numbers = array('i',[84,54,8,7,66])
numbers[-1] = 100
print(numbers)
# Out:
# array('i', [84, 54, 8, 7, 100])

# %%
#Q12.  Create an array of numbers and find the smallest element without using min().  
numbers = array('i',[5,4,2,5,6])
b = sorted(numbers)
print('Smallest integer is',a[0],'.')
# Out:
# Smallest integer is 4 .

# %%
#Q13. Create an array of numbers and find the largest element without using max(). 
numbers = array('i',[5,4,2,5,6])
b = sorted(numbers)
print('Smallest integer is',b[-1],'.')
# Out:
# Smallest integer is 6 .

# %%
#Q14. Create an array and count how many times a given element occurs using count().

numbers = array('i',[5,8,3,6,4,5,7,9,4,2,5])
print(numbers.count(4))
# Out:
# 2
